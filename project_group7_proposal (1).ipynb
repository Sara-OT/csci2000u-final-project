# %% [markdown]
# # CSCI2000U - Scientific Data Analysis
# ## Project Proposal
#
# **Project Group 7**
# **Group Members:**
# Sara Bhatti (100473397), David Dickson (100784459)
#
# **Dataset**
# Name of Dataset: Student Alcohol Consumption
# URL: https://www.kaggle.com/uciml/student-alcohol-consumption
#
# **A brief description of the chosen dataset:**
# 1. This dataset pertains to a survey that was taken of students who were in math and portugese courses in secondary school. It includes information regarding the students social, gender, study, and many other information.
#
# **Description of each of the data attributes:**
# 1. School: the school of the student (binary:'GP'- Gabriel Pereira or 'MS' - Mousinho da Silveira
# 2. Sex: the sex of the student (binary: 'F' - female or 'M' - male
# 3. Age: student's age (numeric: from 15 to 22)
# 4. Address: student's home address type (binary: 'U' - urban or 'R' - rural)
# 5. famsize: family size (binary: 'LE3' - less or equal to 3 or 'GT3' - greater than 3)
# 6. Pstatus: parent's cohabitation status (binary: 'T' - living together or 'A' - apart)
# 7. Medu: mother's education (numeric: 0 - none, 1 - primary education (4th grade), 2 – 5th to 9th grade, 3 – secondary education or 4 – higher education)
# 8. Fedu: father's education (numeric: 0 - none, 1 - primary education (4th grade), 2 – 5th to 9th grade, 3 – secondary education or 4 – higher education)
# 9. Mjob: mother's job (nominal: 'teacher', 'health' care related, civil 'services' (e.g. administrative or police), 'at_home' or 'other')
# 10. Fjob: father's job (nominal: 'teacher', 'health' care related, civil 'services' (e.g. administrative or police), 'at_home' or 'other')
# 11. reason: reason to choose this school (nominal: close to 'home', school 'reputation', 'course' preference or 'other')
# 12. gaurdian: student's guardian (nominal: 'mother', 'father' or 'other')
# 13. traveltime: home to school travel time (numeric: 1 - <15 min., 2 - 15 to 30 min., 3 - 30 min. to 1 hour, or 4 - >1 hour)
# 14. studytime: weekly study time (numeric: 1 - <2 hours, 2 - 2 to 5 hours, 3 - 5 to 10 hours, or 4 - >10 hours)
# 15. failures: number of past class failures (numeric: n if 1<=n<3, else 4)
# 16. schoolsup: extra educational support (binary: yes or no)
# 17. famsup: family educational support (binary: yes or no)
# 18. paid: extra paid classes within the course subject (Math or Portuguese) (binary: yes or no)
# 19. activities: extra-curricular activities (binary: yes or no)
# 20. nursery: attended nursery school (binary: yes or no)
# 21. higher: wants to take higher education (binary: yes or no)
# 22. internet: Internet access at home (binary: yes or no)
# 23. romantic: with a romantic relationship (binary: yes or no)
# 24. famrel: quality of family relationships (numeric: from 1 - very bad to 5 - excellent)
# 25. freetime: free time after school (numeric: from 1 - very low to 5 - very high)
# 26. goout: going out with friends (numeric: from 1 - very low to 5 - very high)
# 27. Dalc: workday alcohol consumption (numeric: from 1 - very low to 5 - very high)
# 28. Walc: weekend alcohol consumption (numeric: from 1 - very low to 5 - very high)
# 29. health: current health status (numeric: from 1 - very bad to 5 - very good)
# 30. absences: number of school absences (numeric: from 0 to 93)
#
# The grades are related to the following courses: math and portuguese
# 1. G1 - frist period grade (0 to 20)
# 2. G2 - second period grade (0 to 20)
# 3. G3 - final grade (0 to 20)

# %%
import csv
import re
from functools import reduce
import numpy as np
import pandas as pd
from datetime import datetime

def math_csv():
    maths = []
    with open('student-mat.csv', 'r') as f:
        for line in csv.DictReader(f):
            maths.append(line) 
        return maths

def port_csv():
    portg = []
    with open('student-por.csv', 'r') as f:
        for line in csv.DictReader(f):
            portg.append(line) 
        return portg  

# the data    
math = math_csv()
port = port_csv()

# %% [markdown]
# ## The code and the analysis of basic characteristics of your dataset
#
# *Getting to know your data*
#
# 1. How many data records do you have? Print how many records.
# 2. What do the few first records look like? Display the top 5 records.
# 3. What are the different job types (for mother and father) in the dataset? Display how many they are and their names.
# 4. Show in a bar plot how much alcohol is consumed by age from 1 to 5.

# %%
# 1. How many data records do you have? Print how many records.

#Math 
len(math)
# Out:
# 395

# %%
# portuguese
len(port)
# Out:
# 649

# %%
# 2. What do the few first records look like? Display the top 5 records.

# math
print(math[:5])
# Out:
# [OrderedDict([('school', 'GP'), ('sex', 'F'), ('age', '18'), ('address', 'U'), ('famsize', 'GT3'), ('Pstatus', 'A'), ('Medu', '4'), ('Fedu', '4'), ('Mjob', 'at_home'), ('Fjob', 'teacher'), ('reason', 'course'), ('guardian', 'mother'), ('traveltime', '2'), ('studytime', '2'), ('failures', '0'), ('schoolsup', 'yes'), ('famsup', 'no'), ('paid', 'no'), ('activities', 'no'), ('nursery', 'yes'), ('higher', 'yes'), ('internet', 'no'), ('romantic', 'no'), ('famrel', '4'), ('freetime', '3'), ('goout', '4'), ('Dalc', '1'), ('Walc', '1'), ('health', '3'), ('absences', '6'), ('G1', '5'), ('G2', '6'), ('G3', '6')]), OrderedDict([('school', 'GP'), ('sex', 'F'), ('age', '17'), ('address', 'U'), ('famsize', 'GT3'), ('Pstatus', 'T'), ('Medu', '1'), ('Fedu', '1'), ('Mjob', 'at_home'), ('Fjob', 'other'), ('reason', 'course'), ('guardian', 'father'), ('traveltime', '1'), ('studytime', '2'), ('failures', '0'), ('schoolsup', 'no'), ('famsup', 'yes'), ('paid', 'no'), ('activities', 'no'), ('nursery', 'no')
# ...

# %%
# portuguese
print(port[:5])
# Out:
# [OrderedDict([('school', 'GP'), ('sex', 'F'), ('age', '18'), ('address', 'U'), ('famsize', 'GT3'), ('Pstatus', 'A'), ('Medu', '4'), ('Fedu', '4'), ('Mjob', 'at_home'), ('Fjob', 'teacher'), ('reason', 'course'), ('guardian', 'mother'), ('traveltime', '2'), ('studytime', '2'), ('failures', '0'), ('schoolsup', 'yes'), ('famsup', 'no'), ('paid', 'no'), ('activities', 'no'), ('nursery', 'yes'), ('higher', 'yes'), ('internet', 'no'), ('romantic', 'no'), ('famrel', '4'), ('freetime', '3'), ('goout', '4'), ('Dalc', '1'), ('Walc', '1'), ('health', '3'), ('absences', '4'), ('G1', '0'), ('G2', '11'), ('G3', '11')]), OrderedDict([('school', 'GP'), ('sex', 'F'), ('age', '17'), ('address', 'U'), ('famsize', 'GT3'), ('Pstatus', 'T'), ('Medu', '1'), ('Fedu', '1'), ('Mjob', 'at_home'), ('Fjob', 'other'), ('reason', 'course'), ('guardian', 'father'), ('traveltime', '1'), ('studytime', '2'), ('failures', '0'), ('schoolsup', 'no'), ('famsup', 'yes'), ('paid', 'no'), ('activities', 'no'), ('nursery', 'no
# ...

# %%
# 3. What are the different job types (for mother and father) in the dataset? 
# Display how many they are and their names.

mjob = set()

for row in data:
    mjob.add(row['Mjob'])
print("Number of Job Type for Mother: " + str(len(mjob)))

print(mjob)
# Out:
# Number of Job Type for Mother: 5
# {'other', 'health', 'teacher', 'services', 'at_home'}

# %%
mjob = set()

for row in data:
    mjob.add(row['Fjob'])
print("Number of Job Type for Father: " + str(len(mjob)))

print(mjob)
# Out:
# Number of Job Type for Father: 5
# {'other', 'health', 'teacher', 'services', 'at_home'}

# %%
# 4. Show in a bar plot how much alcohol is consumed by age from 1 to 5.

import matplotlib.pyplot as plt

x = []
y = []
  
with open('student-mat.csv','r') as csvfile:
    graph = csv.reader(csvfile, delimiter = ',')
    headers = next(graph, None)
    headers
      
    for row in graph:
        x.append(row[2])
        y.append(row[27])
  
plt.bar(x, y, color = 'c', width = 0.50, label = " ")
plt.ylabel('Dalc')
plt.xlabel('Age')
plt.title('Alcohol Consumption on Weekends')
plt.legend()
plt.show()

# %% [markdown]
# ## Proposal and Motivation
#
# *Why did you choose this dataset over others?*
#
# We wanted to see the impact that alcohol consumption had on students in high school and how it affected their grades.
#
# *Was there any other dataset you also found interesting?*
#
# We were also looking at the dataset "Alcohol Consumption" and "Happiness and Alcohol Consumption".
#
# The first dataset mentioned focuses on in what countries people drink the most beer, wine, and spirits. It had five columns and was a basic overall view of alcohol consumption.
#
# The second dataset focused on alcohol consumption versus the happiness score. The data was taken from over a hundred countries and it included peoples happiness score where it was a metric measured in 2016 where sampled people were asked to rate their happiness, the Human Development Index by the UN Development Program, the GDP index, beer, spirit, and wine per capita.
#
#
# *What are the data analysis questions you want to use this dataset for?*
#
#     •	At least 5 questions for proposal, you may include more questions in the actual final project report
#     •	What methods do you expect to apply when you process the data to answer these questions?
#
# *Do you see any potential for data science applications using this data?*
#
#     •	Examples: models for prediction, recommendation, data visualization, etc.

# %%
#The first question would be is the age related to the student alcohol consumption?
#The second question is does a person’s sex relate to student alcohol consumption?
#The third is do accommodations correlate with the alcohol consumption, including whether they live rural or in the city, as well as their family size?
#The fourth is do the parents situations have a correlation with the amount of alcohol that a student consumes? This relates to their education and their job? 
#The fifth is there a correlation between drinking and their parents cohabitation?

# %%
df_math = pd.DataFrame(math)
df_math["age"] = pd.to_numeric(df_math["age"])
#df_math.info()

print("Age Mean: {}, Age Standard deviation: {}".format(df_math['age'].mean(), df_math['age'].std()))
df_math.describe(exclude=[object])
# Out:
# Age Mean: 16.696202531645568, Age Standard deviation: 1.2760427246056245
#               age
# count  395.000000
# mean    16.696203
# std      1.276043
# min     15.000000
# 25%     16.000000
# 50%     17.000000
# 75%     18.000000
# max     22.000000

# %%
#The first question would be is the age related to the student alcohol consumption?


df_math[["age", "Walc", "Dalc"]] = df_math[["age", "Walc", "Dalc"]].apply(pd.to_numeric)
#df_math.info()
#age_walc = df_math.groupby("Dalc")["Walc"].count().reset_index()
#age_walc
#age_walc.plot.barh()
#age_count = df_math['age'].value_counts().sort_values(ascending = False)
#dalc_count = df_math['Walc'].value_counts().sort_values(ascending = False)
#age_count
#dalc_count

#age_dalc = df_math.groupby("age")["Dalc"].count().reset_index()
#age_dalc.plot(kind='bar', figsize=(12,6), x="age")
#plt.title('Age and Weekday Drinking')

#Age & Dalc
weekday = df_math['age'].value_counts().iloc[:8].index
weekday
plt.figure(figsize=(18, 6))
sns.countplot(x="age", data=df_math, hue='Dalc', order=weekday,palette='mako')
plt.xticks(size=25, rotation=0)
plt.title("Workday Alcohol Consumption by Age",fontsize=20)
plt.show()

#Answer for the workday 16 year olds are seen to drink the most and then it gradually decreases

# %%
#age_dalc = df_math.groupby("age")["Walc"].count().reset_index()
#age_dalc.plot(kind='bar', figsize=(12,6), x="age")
#plt.title('Age and Weekend Drinking')

weekday = df_math['age'].value_counts().iloc[:8].index
weekday
plt.figure(figsize=(18, 6))
sns.countplot(x="age", data=df_math, hue='Walc', order=weekday,palette='mako')
plt.xticks(size=25, rotation=0)
plt.title("Weekend Alcohol Consumption by Age",fontsize=20)
plt.show()
#For the weekend 18 year olds are seen to drink the most. They have the largest portion of heavy drinkers. After 18 it seems to shallow out.
#From 15 to 18 it slowly builds and hits it peak at 18.

# %%
df_port = pd.DataFrame(port)
df_port
# Out:
#     school sex age address famsize Pstatus  ... Walc health absences  G1  G2  G3
# 0       GP   F  18       U     GT3       A  ...    1      3        4   0  11  11
# 1       GP   F  17       U     GT3       T  ...    1      3        2   9  11  11
# 2       GP   F  15       U     LE3       T  ...    3      3        6  12  13  12
# 3       GP   F  15       U     GT3       T  ...    1      5        0  14  14  14
# 4       GP   F  16       U     GT3       T  ...    2      5        0  11  13  13
# ..     ...  ..  ..     ...     ...     ...  ...  ...    ...      ...  ..  ..  ..
# 644     MS   F  19       R     GT3       T  ...    2      5        4  10  11  10
# 645     MS   F  18       U     LE3       T  ...    1      1        4  15  15  16
# 646     MS   F  18       U     GT3       T  ...    1      5        6  11  12   9
# 647     MS   M  17       U     LE3       T  ...    4      2        6  10  10  10
# 648     MS   M  18       R     LE3       T  ...    4      5        4  10  11  11
#
# ...

# %%
#The second question is does a person’s sex relate to student alcohol consumption?

sex = df_math.groupby("sex")["Dalc"].count().reset_index()
sex.plot(kind='bar', figsize=(12,6), x="sex")
plt.title('Alcohol Consumption on Workdays by Sex')
# Out:
# Text(0.5, 1.0, 'Alcohol Consumption on Workdays by Sex')

# %%
sex = df_math.groupby("sex")["Walc"].count().reset_index()
sex.plot(kind='bar', figsize=(12,6), x="sex")
plt.title('Alcohol Consumption on Weekends by Sex')
# Out:
# Text(0.5, 1.0, 'Alcohol Consumption on Weekends by Sex')

# %%
age_walc = df_math.groupby("Dalc")["Walc"].count().reset_index()
age_walc
age_walc.plot.barh()

# %%
#The third is do accommodations correlate with the alcohol consumption, 
#including whether they live rural or in the city, as well as their family size?

urban_rural = df_math.groupby("address")["Dalc"].count().reset_index()
urban_rural.plot(kind='bar', figsize=(12,6), x="address")
plt.title('Alcohol Consumption on Workdays by Address')


urban_rural = df_math.groupby("address")["Walc"].count().reset_index()
urban_rural.plot(kind='bar', figsize=(12,6), x="address")
plt.title('Alcohol Consumption on Weekends by Address')
# Out:
# Text(0.5, 1.0, 'Alcohol Consumption on Weekends by Address')

# %%
#The third is do accommodations correlate with the alcohol consumption, 
#including whether they live rural or in the city, as well as their family size?

address = df_math['address'].value_counts().iloc[:2].index
address

plt.figure(figsize=(18, 6))
sns.countplot(x="address", data=df_math, hue='Dalc', order=address,palette='icefire')
plt.xticks(size=25, rotation=0)
plt.title("Workday Alcohol Consumption by Address",fontsize=20)
plt.show()


plt.figure(figsize=(18, 6))
sns.countplot(x="address", data=df_math, hue='Walc', order=address,palette='icefire')
plt.xticks(size=25, rotation=0)
plt.title("Weekend Alcohol Consumption by Address",fontsize=20)
plt.show()
#As shown here it can be seen that the alcohol consumption is far greater in the urban areas for students than in the rural areas

# %%
#The fourth is do the parents situations have a correlation with the amount of 
#alcohol that a student consumes? This relates to their education and their job? 

#Dalc
medu = df_math.groupby("Medu")["Dalc"].count().reset_index()
medu.plot(kind='bar', figsize=(12,6), x="Medu")
plt.title('Alcohol Consumption on Workdays of Students and Mothers Education')


medu = df_math['Medu'].value_counts().iloc[:].index

plt.figure(figsize=(18, 6))
sns.countplot(x="Medu", data=df_math, hue='Dalc', order=medu,palette='icefire')
plt.xticks(size=25, rotation=0)
plt.title("Workday Alcohol Consumption of Student and Mothers Education",fontsize=20)
plt.show()


#Walc
medu = df_math.groupby("Medu")["Walc"].count().reset_index()
medu.plot(kind='bar', figsize=(12,6), x="Medu")
plt.title('Alcohol Consumption on Weekends of Students and Mothers Education')


medu = df_math['Medu'].value_counts().iloc[:].index

plt.figure(figsize=(18, 6))
sns.countplot(x="Medu", data=df_math, hue='Walc', order=medu,palette='icefire')
plt.xticks(size=25, rotation=0)
plt.title("Weekends Alcohol Consumption of Student and Mothers Education",fontsize=20)
plt.show()

# %%
#The fifth is there a correlation between drinking and their parents cohabitation?

#Dalc
pstatus = df_math['Pstatus'].value_counts().iloc[:].index

plt.figure(figsize=(18, 6))
sns.countplot(x="Pstatus", data=df_math, hue='Dalc', order=pstatus,palette='icefire')
plt.xticks(size=25, rotation=0)
plt.title("Workday Alcohol Consumption and Parents Cohabitation Status",fontsize=20)
plt.show()

# %%
#Walc
plt.figure(figsize=(18, 6))
sns.countplot(x="Pstatus", data=df_math, hue='Walc', order=pstatus,palette='icefire')
plt.xticks(size=25, rotation=0)
plt.title("Weekend Alcohol Consumption and Parents Cohabitation Status",fontsize=20)
plt.show()

# %%
#family relationship and parents cohabitation status
famrel = df_math['famrel'].value_counts().iloc[:].index

plt.figure(figsize=(18, 6))
sns.countplot(x="famrel", data=df_math, hue='Pstatus', order=famrel,palette='icefire')
plt.xticks(size=25, rotation=0)
plt.title("Quality of Family Relationship and Parents Cohabitation Status",fontsize=20)
plt.show()
#This shows that the students consume more alcohol when both parents are together

# %%
g1 = df_math['G1'].value_counts().iloc[:].index

plt.figure(figsize=(18, 6))
sns.countplot(x="G1", data=df_math, hue='Dalc', order=g1,palette='icefire')
plt.xticks(size=25, rotation=0)
plt.title("G1 and Alcohol",fontsize=20)
plt.show()

g2 = df_math['G2'].value_counts().iloc[:].index

plt.figure(figsize=(18, 6))
sns.countplot(x="G2", data=df_math, hue='Dalc', order=g2,palette='icefire')
plt.xticks(size=25, rotation=0)
plt.title("G2 and Alcohol",fontsize=20)
plt.show()

g3 = df_math['G3'].value_counts().iloc[:].index

plt.figure(figsize=(18, 6))
sns.countplot(x="G3", data=df_math, hue='Dalc', order=g3,palette='icefire')
plt.xticks(size=25, rotation=0)
plt.title("G3 and Alcohol",fontsize=20)
plt.show()

# %%
#The methods to answer these questions would be to graph the data sets to see if there is a correlation between the columns.
# Some methods that are expected to be applied is calculation the average, mode, mean for certain columns. 
#As well as graphing the data. Other calculations that are expected are standard deviation to see 
#if there are many or little outliers within the datadata.

# %%
#There are potential data science applications for this. All of these questions can likely be graphed, and once they are it will be a lot easier to see if there is positive or negative trends in the data sets. 
#Based off of the graphs predictions, recommendations and visualizations can be processed.

# %% [markdown]
# Technical Report

# %% [markdown]
# Introduction
# This topic for this project that was chosen is alcohol consumption and students. We chose this topic since it relates to us directly being students. This is an interesting topic to see what affects students and alcohol consumption. The group members for our group are Sara and David.

# %% [markdown]
# \\Description of Data#
# The data was collected from surveys. The data was taken from the website kaggle.
# The url to access the dataset is as follows https://www.kaggle.com/uciml/student-alcohol-consumption.
# The source of the data is the kaggle website.

# %% [markdown]
# Analysis of Data#
# The data given shows the school the student attends, the sex of the student, the age of the student, the address of the student, the family size, the parents cohabitation status, the mother's and the father's education, and the mother's and the father's job.

# %% [markdown]
# Exploratory Data

# %% [markdown]
# Potential Data Science
# Some potential data science would be to see how all of these factors affect on if a student is drinking or not. And to see if there is a correlation between the different factors and if this data can be used to predict if a student will be brought into alcoholism.

# %% [markdown]
# Conclusion
# The limitations of this is that it is just taking a general look on these items and then projecting an assumption from them.

# %% [markdown]
# Blog Post

# %% [markdown]
# Title#
# The Correlation of student environmental factors to the amont of alcohol consumed

# %% [markdown]
# About us
# Sara Bhatti
# David Dickson

# %% [markdown]
# Introduction
#
#  The topic being discussed is how student environmental factors affect the amount of alcohol consumed. This project will look at how the environmental factors can be used to project and predict how much a student partakes in alcoholism. This dataset is from kaggle and is called student alcohol consumption. The data itself was taken from surveys taken but students.

# %% [markdown]
# Discussion
#
# One interesting thing about the data given is that it showed that people in school drank more in their teen years then in their young adult years for week days. This showed that the peak drinking age was 16 and that after 16 it gradually became less.
# For the weekends it was shown that 18 year old drank the most and after that it seemed to decrease, with and increase in drinking on weekends from 15 to 18.
#
# Another discovery found from this study was that both on weekdays and on weekends females drank more than males did as a whole.
#
#
# It was found that the place where the students lived also affected as to how much that they drank alcohol. Students in urban environments consumed far more alcohol then students living in rural environments.
#
# It was also found that the more stable an income for the students parents regardless of it being the mother or father showed they had more disposable income and as such drank more alcohol.
#
# Students where both parents lived together had more disposable income and as such drank more.
#
# A short coming of this dataset is that there are far more teenagers that were surveyed than people above the age of 20. For example only one 22 year old was sampled.

# %% [markdown]
# Conclusion
#
# It was found that students that seemed to have more disposable income from parents or other environmental factors actually drank more then students with less. This can be seen because students where their parents are together consumed more alcohol then students with separated parents. Also the higher an education of the parents for the students the more alcohol that they would drink.
#
#
# Students in rural areas consumed less than students in urban areas. It was also found the females consume more alcohol than males and the peak drinking range is 16-18 years old.
#
#
# This data taught us that environmental factos can influence as to how much a student will drink.
